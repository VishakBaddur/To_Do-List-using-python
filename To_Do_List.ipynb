# %%
# Initialize an empty list to store the tasks
tasks = []

# Function to add a task to the list
def add_task():
    task = input("Enter a task: ")
    tasks.append(task)
    print("Task added successfully!")

# Function to view the tasks
def view_tasks():
    if not tasks:
        print("No tasks to display.")
    else:
        print("Tasks:")
        for i, task in enumerate(tasks, start=1):
            print(f"{i}. {task}")

# Function to remove a task by index
def remove_task():
    view_tasks()
    if not tasks:
        return
    try:
        index = int(input("Enter the task number to remove: "))
        if 1 <= index <= len(tasks):
            removed_task = tasks.pop(index - 1)
            print(f"Task '{removed_task}' removed successfully!")
        else:
            print("Invalid task number.")
    except ValueError:
        print("Invalid input. Please enter a valid task number.")

# Main loop
while True:
    print("\nOptions:")
    print("1. Add Task")
    print("2. View Tasks")
    print("3. Remove Task")
    print("4. Quit")
    
    choice = input("Enter your choice (1/2/3/4): ")

    if choice == '1':
        add_task()
    elif choice == '2':
        view_tasks()
    elif choice == '3':
        remove_task()
    elif choice == '4':
        print("Goodbye!")
        break
    else:
        print("Invalid choice. Please enter 1, 2, 3, or 4.")
# Out:
# Options:
# 1. Add Task
# 2. View Tasks
# 3. Remove Task
# 4. Quit
# Enter your choice (1/2/3/4): 1
# Enter a task: bath
# Task added successfully!
#
# Options:
# 1. Add Task
# 2. View Tasks
# 3. Remove Task
# 4. Quit
# Enter your choice (1/2/3/4): 1
# Enter a task: laundry
# Task added successfully!
#
# Options:
# 1. Add Task
# 2. View Tasks
# 3. Remove Task
# 4. Quit
# Enter your choice (1/2/3/4): 1
# Enter a task: grocery shopping
# Task added successfully!
#
# Options:
# 1. Add Task
# 2. View Tasks
# 3. Remove Task
# 4. Quit
# Enter your choice (1/2/3/4): 2
# Tasks:
# 1. bath
# 2. laundry
# 3. grocery shopping
#
# Options:
# 1. Add Task
# 2. View Tasks
# 3. Remove Task
# 4. Quit
# Enter your choice (1/2/3/4): 3
# Tasks:
# 1. bath
# 2. laundry
# 3. grocery shopping
# Enter the task number to remove: bath
# Invalid input. Please enter a valid task number.
#
# Options:
# 1. Add Task
# 2. View Tasks
# 3. Remove Task
# 4. Quit
# Enter your choice (1/2/3/4): 3
# Tasks:
# 1. bath
# 2. laundry
# 3. grocery shopping
# Enter the task number to remove: 1
# Task 'bath' removed successfully!
#
# Options:
# 1. Add Task
# 2. View Tasks
# 3. Remove Task
# 4. Quit
# Enter your choice (1/2/3/4): 2
# Tasks:
# 1. laundry
# 2. grocery shopping
#
# Options:
# 1. Add Task
# 2. View Tasks
# 3. Remove Task
# 4. Quit
# Enter your choice (1/2/3/4): 4
# Goodbye!
